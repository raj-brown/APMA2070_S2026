# %% [markdown]
# ## Poisson equation with constant coefficient
# The Poisson equation on a unit disk with zero Dirichlet boundary condition can be written as $- \nabla \cdot (c\nabla  u) = 1$  in $\Omega$, $u=0$ on $\partial \Omega$ , where $\Omega$  is the unit disk. The exact solution when  is
# $$
# u(x,y)= \frac{1-x^2-y^2}{4}
# $$
#
#
# Here, objective is to compute the coefficient $c$ using PINN and we assume $c$ is scalar.

# %%
# =========================================================
# Import the required modules
# =========================================================
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt


# =========================================================
# Problem description: circular domain of radius r
# =========================================================
r = 1

# Create points on the boundary of the circle for visualization
theta = np.linspace(0, 2 * np.pi, 100)
x = r * np.cos(theta)
y = r * np.sin(theta)

# Plot the circular domain
plt.plot(x, y, "-b", lw=1.5)
plt.axis("equal")


# =========================================================
# Generate collocation points inside the circle
# =========================================================
def generate_collocation_points(radius, num_samples):
    """
    Generate random points uniformly inside a circle.

    Parameters:
        radius : float
            Radius of the circle
        num_samples : int
            Number of points to generate

    Returns:
        xy : array of shape (num_samples, 2)
            Random points inside the circle
    """

    # Random radius:
    # sqrt is used so points are uniformly distributed over area
    r = radius * np.sqrt(np.random.rand(num_samples, 1))

    # Random angle between 0 and 2pi
    theta = np.random.uniform(0, 2 * np.pi, num_samples)

    # Convert polar coordinates to Cartesian coordinates
    x = r * np.cos(theta).reshape(-1, 1)
    y = r * np.sin(theta).reshape(-1, 1)

    # Combine x and y into one array
    xy = np.concatenate((x, y), axis=1)
    return xy


# =========================================================
# Generate boundary points on the circle
# =========================================================
def generate_boundary_points(radius, num_samples):
    """
    Generate equally spaced points on the boundary of the circle.
    """

    theta = np.linspace(0, 2 * np.pi, num_samples)

    # Boundary coordinates
    x = radius * np.cos(theta).reshape(-1, 1)
    y = radius * np.sin(theta).reshape(-1, 1)

    # Combine x and y
    xy = np.concatenate((x, y), axis=1)
    return xy


# =========================================================
# Analytical / exact solution
# =========================================================
def analytical_sol(xy):
    """
    Exact solution:
        u(x,y) = 1/4 * (1 - x^2 - y^2)

    Parameters:
        xy : array of shape (N, 2)

    Returns:
        u : array of shape (N, 1)
    """
    u = (1 / 4.0) * (1 - xy[:, 0] * xy[:, 0] - xy[:, 1] * xy[:, 1])
    u = u.reshape(-1, 1)
    return u


# =========================================================
# Generate validation data inside the circle
# =========================================================
def generate_validation_data(radius, num_samples):
    """
    Generate random validation points inside the circle.
    """

    r = radius * np.sqrt(np.random.rand(num_samples, 1))
    theta = np.random.uniform(0, 2 * np.pi, num_samples)

    x = r * np.cos(theta).reshape(-1, 1)
    y = r * np.sin(theta).reshape(-1, 1)

    # Combine x and y
    xy = np.concatenate((x, y), axis=1)
    return xy


# =========================================================
# Define the Physics-Informed Neural Network (PINN)
# =========================================================
class PINN(nn.Module):
    def __init__(self, input_size, num_neurons, output_size):
        """
        Neural network with:
            - one learnable scalar parameter c
            - two hidden layers
            - tanh activation
        """
        super(PINN, self).__init__()

        # Unknown physical parameter to be learned
        self.c = nn.Parameter(torch.tensor(0.5))

        # Network layers
        self.fc1 = nn.Linear(input_size, num_neurons)
        self.activation_1 = nn.Tanh()

        self.fc2 = nn.Linear(num_neurons, num_neurons)
        self.activation_2 = nn.Tanh()

        self.fc3 = nn.Linear(num_neurons, output_size)

    def get_parameter(self):
        """
        Return the learnable physical parameter c.
        """
        return self.c

    def forward(self, x):
        """
        Forward pass through the neural network.
        """
        x = self.fc1(x)
        x = self.activation_1(x)

        x = self.fc2(x)
        x = self.activation_2(x)

        x = self.fc3(x)

        return x


# =========================================================
# Compute PDE residual
# =========================================================
def net_f(model, xy_f):
    """
    Compute the PDE residual at collocation points.

    This code corresponds to:
        c * (u_xx + u_yy) + 1 = 0

    where c is an unknown parameter learned by the model.
    """

    # Predict u(x,y)
    u = model(xy_f)

    # First derivatives of u with respect to x and y
    grad_u = torch.autograd.grad(
        u,
        xy_f,
        grad_outputs=torch.ones_like(u),
        create_graph=True
    )[0]

    # Second derivative term in x direction
    u_xx = torch.autograd.grad(
        model.get_parameter() * grad_u[:, 0],
        xy_f,
        grad_outputs=torch.ones_like(grad_u[:, 0]),
        create_graph=True
    )[0][:, 0]

    # Second derivative term in y direction
    u_yy = torch.autograd.grad(
        model.get_parameter() * grad_u[:, 1],
        xy_f,
        grad_outputs=torch.ones_like(grad_u[:, 1]),
        create_graph=True
    )[0][:, 1]

    # PDE residual
    return u_xx + u_yy + 1.0


# =========================================================
# Compute predicted data values
# =========================================================
def net_d(model, x_d):
    """
    Predict u(x,y) at data points.
    """
    u = model(x_d)
    return u


# =========================================================
# Loss function
# =========================================================
def loss_fn(model, xy_f, xy_d, u_d):
    """
    Total loss = data loss + physics loss

    data loss   -> fit known data values
    physics loss -> enforce PDE residual
    """

    # PDE residual at collocation points
    f = net_f(model, xy_f)

    # Prediction at data points
    d = net_d(model, xy_d)

    # Physics loss
    loss_f = (f ** 2).mean()

    # Data loss
    loss_d = ((d - u_d) ** 2).mean()

    # Total loss
    loss = loss_d + 0.01 * loss_f
    return loss


# =========================================================
# Main training script
# =========================================================
if __name__ == "__main__":
    r = 1.0
    num_collocation_points = 1000
    num_boundary_points = 100
    num_data = 50

    # -----------------------------------------------------
    # Initialize collocation points inside the domain
    # -----------------------------------------------------
    xy_f = torch.tensor(
        generate_collocation_points(r, num_collocation_points),
        requires_grad=True,
        dtype=torch.float32
    )

    # -----------------------------------------------------
    # Initialize boundary points
    # -----------------------------------------------------
    xy_b = torch.tensor(
        generate_boundary_points(r, num_boundary_points),
        dtype=torch.float32
    )

    # Boundary condition: u = 0 on the boundary
    u_b = torch.zeros((xy_b.size(0), 1), dtype=torch.float32)

    # -----------------------------------------------------
    # Initialize interior data points
    # -----------------------------------------------------
    xy_d = generate_collocation_points(r, num_data)
    u_d = analytical_sol(xy_d)

    xy_d = torch.tensor(xy_d, dtype=torch.float32)
    u_d = torch.tensor(u_d, dtype=torch.float32)

    # -----------------------------------------------------
    # Concatenate boundary and interior data points
    # -----------------------------------------------------
    xy_data = torch.concatenate((xy_b, xy_d), axis=0)
    u_data = torch.concatenate((u_b, u_d), axis=0)

    # -----------------------------------------------------
    # Training settings
    # -----------------------------------------------------
    nIters = 15000
    d_in = 2
    num_neurons = 60
    d_out = 1
    lr = 1e-3

    # Create model
    model = PINN(d_in, num_neurons, d_out)

    # Optimizer updates both neural network weights and parameter c
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    # Store loss history
    loss_history = []

    # Store c history
    c_history = np.zeros(shape=(nIters, 1))

    # -----------------------------------------------------
    # Start training
    # -----------------------------------------------------
    for it in range(0, nIters):
        optimizer.zero_grad()

        # Compute loss
        loss = loss_fn(model, xy_f, xy_d, u_d)

        # Backpropagation
        loss.backward()

        # Update parameters
        optimizer.step()

        c = model.get_parameter().detach().cpu().numpy()
        c_history[it] = c
        loss_history.append(loss.detach().cpu().numpy())


        # Print progress every 1000 iterations
        if it % 1000 == 0:
            c = model.get_parameter().detach().cpu().numpy()
            print(f"Epoch {it+1}/{nIters}, Loss: {loss:.8f} and c: {c}")



# =========================================================
# Postprocess the output
# =========================================================
def prediction(model, xy):
    """
    Predict u(x,y) using the trained model.
    """
    u_val = model(xy)
    return u_val.detach().cpu().numpy()


def save_model(trained_model):
    """
    Save the trained model to a file.
    """
    torch.save(trained_model, "model.pth")


def load_model(model_name):
    """
    Load a saved model.
    """
    torch.load(model_name)


# =========================================================
# Validation
# =========================================================

# Number of validation points
num_val_dat = 100000

# Generate validation points inside the circle
xy_val = generate_collocation_points(r, num_val_dat)

# Compute exact solution at validation points
u_true = analytical_sol(xy_val)

# Convert validation points to tensor
xy_val_torch = torch.tensor(xy_val, dtype=torch.float32)

# Predict using trained model
u_pred = prediction(model, xy_val_torch)

# Relative L2 error
l2_error = np.linalg.norm(u_pred - u_true) / np.linalg.norm(u_true)

print(f"Relative l2 error is: {l2_error*100:0.4f}%")


# =========================================================
# Plot 1: Predicted solution
# =========================================================
plt.scatter(xy_val[:, 0], xy_val[:, 1], c=u_pred, s=5)
plt.title("Predicted")
plt.axis("equal")
plt.colorbar()
plt.show()


# =========================================================
# Plot 2: Reference / exact solution
# =========================================================
plt.scatter(xy_val[:, 0], xy_val[:, 1], c=u_true, s=5)
plt.title("Reference")
plt.axis("equal")
plt.colorbar()
plt.show()


# =========================================================
# Plot 3: Pointwise error
# =========================================================
plt.scatter(xy_val[:, 0], xy_val[:, 1], c=np.abs(u_pred - u_true), s=5)
plt.title("Pointwise absolute error")
plt.axis("equal")
plt.colorbar()
plt.show()


# =========================================================
# Plot 4: Convergence of c and loss
# =========================================================
iterations = np.arange(nIters)
plt.figure()
plt.semilogy(iterations, c_history, 'b-', linewidth=2, label="c")
plt.semilogy(iterations, loss_history, 'r-', linewidth=2, label="Loss")
plt.xlabel("Iteration")
plt.ylabel("Learned parameter c")
plt.title("Convergence of parameter c during training")
plt.grid(True)
plt.show()
# Out:
# Epoch 1/15000, Loss: 0.02985404 and c: 0.5009999871253967
# Epoch 1001/15000, Loss: 0.00000584 and c: 0.9749026894569397
# Epoch 2001/15000, Loss: 0.00000194 and c: 1.0004562139511108
# Epoch 3001/15000, Loss: 0.00000123 and c: 1.0018376111984253
# Epoch 4001/15000, Loss: 0.00000076 and c: 1.0018565654754639
# Epoch 5001/15000, Loss: 0.00000063 and c: 1.0017787218093872
# Epoch 6001/15000, Loss: 0.00000054 and c: 1.001660943031311
# Epoch 7001/15000, Loss: 0.00000045 and c: 1.0015405416488647
# Epoch 8001/15000, Loss: 0.00000038 and c: 1.0014073848724365
# Epoch 9001/15000, Loss: 0.00000032 and c: 1.0012727975845337
# Epoch 10001/15000, Loss: 0.00000028 and c: 1.0011334419250488
# Epoch 11001/15000, Loss: 0.00000063 and c: 1.0011589527130127
# Epoch 12001/15000, Loss: 0.00014443 and c: 1.0022659301757812
# Epoch 13001/15000, Loss: 0.00000044 and c: 1.000617265701294
# Epoch 14001/15000, Loss: 0.00000022 and c: 1.0007805824279785
# Relative l2 error is: 0.1625%
