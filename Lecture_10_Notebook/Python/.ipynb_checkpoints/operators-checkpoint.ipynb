# %% [markdown]
# ## Deep Neural Operators

# %% [markdown]
# ## Table of Contents
# #### 1. [DeepONet for Antiderivative Operators in TF2.0](#DeepONet-for-Antiderivative-Operators-in-TF2.0)
# #### 1. [DeepONet for Antiderivative Operators in JAX](#DeepONet-for-Antiderivative-Operators-in-JAX)
# #### 2. [FNO for Burger's Equation](#Fourier-Neural-Operator-(FNO)-for-Burgers-Equation)

# %% [markdown]
# ## DeepONet for Antiderivative Operators in TF2.0

# %%
import tensorflow.compat as tf
import numpy as np
import scipy.io as io
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io as io
import sys
sys.path.insert(0, 'Utilities/')
import os

from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec


d = np.load("antiderivative_aligned_train.npz", allow_pickle=True)
v_train, x_train, u_train = d["X"][0], d["X"][1], d["y"]

d = np.load("antiderivative_aligned_test.npz", allow_pickle=True)
v_test, x_test, u_test = d["X"][0], d["X"][1], d["y"]


####### Row 0: u(t,x) ##################    
gs0 = gridspec.GridSpec(1,1)
#gs0.update(top=1-0.06, bottom=1-1/3, left=0.15, right=0.85, wspace=0)
ax = plt.subplot(gs0[:, :])
ax.plot(x_train, v_train[10,:], '-k', lw=2.0, label="$v(x)$")
ax.plot(x_train, u_train[10,:], '-b', lw=2.0, label="$u(x)$")
ax.plot(x_train, v_test[100,:], '--k', lw=2.0, label="$v(x)$")
ax.plot(x_train, u_test[100,:], '--b', lw=2.0, label="$u(x)$")
ax.set_xlabel('$x$')
ax.set_ylabel('$u$')
ax.legend(frameon=False, loc = 'best')
ax.set_title('$v \sim \mathcal{GP}(0, cov(x,x))$', fontsize = 10)
#ax.set_xlim([0,1.2])
#ax.set_ylim([-1.1,1.1])
#ax.axis('square')
plt.savefig("Data.png", dpi=300)

# %%
import os
import time
import tensorflow as tf
import numpy as np
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as io
np.random.seed(1234)
import sys

# Define a simple deep neural network helper class
class DNN:
    def __init__(self):
        # No attributes are initialized here
        pass

    # Initialize weights and biases for a fully connected neural network
    def hyper_initial(self, layers):
        L = len(layers)   # Total number of layers
        W = []            # List to store weight matrices
        b = []            # List to store bias vectors

        # Loop through each layer pair and initialize parameters
        for l in range(1, L):
            in_dim = layers[l-1]   # Input dimension of current layer
            out_dim = layers[l]    # Output dimension of current layer

            # Standard deviation based on Xavier-like initialization
            std = np.sqrt(2.0/(in_dim+out_dim))

            # Initialize weights and biases with truncated normal distribution
            weight = tf.Variable(
                tf.random.truncated_normal(shape=(in_dim, out_dim), stddev=std)
            )
            bias = tf.Variable(
                tf.random.truncated_normal(shape=(1, out_dim), stddev=std)
            )

            W.append(weight)
            b.append(bias)

        return W, b

    # Forward pass for the Branch network
    def fnn_B(self, X, W, b):
        A = X
        A = tf.cast(A, dtype=tf.float32)  # Ensure input is float32
        L = len(W)

        # Apply hidden layers with tanh activation
        for i in range(L-1):
            A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))

        # Final output layer without activation
        Y = tf.add(tf.matmul(A, W[-1]), b[-1])
        return Y

    # Forward pass for the Trunk network
    def fnn_T(self, X, W, b):
        A = X  # Input normalization could be applied here if needed
        A = tf.cast(A, dtype=tf.float32)  # Ensure input is float32
        L = len(W)

        # Apply hidden layers with tanh activation
        for i in range(L-1):
            A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))

        # Final output layer without activation
        Y = tf.add(tf.matmul(A, W[-1]), b[-1])
        return Y


# =========================
# Load training data
# =========================
d = np.load("antiderivative_aligned_train.npz", allow_pickle=True)
v_train, x_train, u_train = d["X"][0], d["X"][1], d["y"]

# Load test data
d = np.load("antiderivative_aligned_test.npz", allow_pickle=True)
v_test, x_test, u_test = d["X"][0], d["X"][1], d["y"]

# Input dimension for Branch network
u_dim = 100

# Shared latent output dimension for Branch and Trunk networks
G_dim = 100

# Branch network architecture: input -> 2 hidden layers -> output
layers_f = [u_dim] + [40]*2 + [G_dim]

# Input dimension for Trunk network
x_dim = 1

# Trunk network architecture: input -> 2 hidden layers -> output
layers_x = [x_dim] + [40]*2 + [G_dim]

# Create model instance
model = DNN()


# Single training step
def train_step(model, W_branch, b_branch, W_trunk, b_trunk, v, x, u, opt):
    # Collect all trainable variables
    train_vars = W_branch + b_branch + W_trunk + b_trunk

    with tf.GradientTape() as tape:
        # Watch trainable variables for automatic differentiation
        tape.watch([W_branch, b_branch, W_trunk, b_trunk])

        # Forward pass through Branch and Trunk networks
        u_out_branch = model.fnn_B(v, W_branch, b_branch)
        u_out_trunk = model.fnn_T(x, W_trunk, b_trunk)

        # Combine Branch and Trunk outputs using einsum
        # Produces operator output prediction
        u_pred = tf.einsum('ij,kj->ik', u_out_branch, u_out_trunk)

        # Mean squared error loss
        loss = tf.reduce_mean(tf.square(u_pred - u))

    # Compute gradients and update parameters
    grads = tape.gradient(loss, train_vars)
    opt.apply_gradients(zip(grads, train_vars))

    return loss, u_pred


# Single test/evaluation step
def test_step(model, W_branch, b_branch, W_trunk, b_trunk, v, x, u, opt):
    # Convert numpy arrays to TensorFlow tensors
    x_test_tf = tf.convert_to_tensor(x, dtype=tf.float32)
    v_test_tf = tf.convert_to_tensor(v, dtype=tf.float32)
    u_test_tf = tf.convert_to_tensor(u, dtype=tf.float32)

    # Forward pass through Branch and Trunk networks
    u_out_branch = model.fnn_B(v_test_tf, W_branch, b_branch)
    u_out_trunk = model.fnn_T(x_test_tf, W_trunk, b_trunk)

    # Combine outputs to form prediction
    u_pred = tf.einsum('ij,kj->ik', u_out_branch, u_out_trunk)

    # Mean squared error loss
    loss = tf.reduce_mean(tf.square(u_pred - u))

    return loss, u_pred


# Initialize Branch and Trunk network parameters
W_branch, b_branch = model.hyper_initial(layers_f)
W_trunk, b_trunk = model.hyper_initial(layers_x)

# Training configuration
n = 0
nmax = 10000
lr = 5e-4

# Track timing
start_time = time.perf_counter()
time_step_0 = time.perf_counter()

# Adam optimizer
optimizer = tf.optimizers.Adam(learning_rate=lr)

# Lists to store errors and losses during training
train_err_list = []
test_err_list = []
train_loss_list = []
test_loss_list = []

# =========================
# Training loop
# =========================
while n <= nmax:
    # Convert training data to TensorFlow tensors
    x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
    v_train_tf = tf.convert_to_tensor(v_train, dtype=tf.float32)
    u_train_tf = tf.convert_to_tensor(u_train, dtype=tf.float32)

    # Perform one training step
    loss_train, u_train_pred = train_step(
        model, W_branch, b_branch, W_trunk,
        b_trunk, v_train_tf, x_train_tf, u_train_tf,
        optimizer
    )

    # Compute relative L2 training error
    err_train = np.mean(
        np.linalg.norm(u_train - u_train_pred, 2, axis=1) /
        np.linalg.norm(u_train, 2, axis=1)
    )

    # Perform one test step
    loss_test, u_test_pred = test_step(
        model, W_branch, b_branch, W_trunk, b_trunk,
        v_test, x_test, u_test, optimizer
    )

    # Compute relative L2 test error
    err_test = np.mean(
        np.linalg.norm(u_test - u_test_pred, 2, axis=1) /
        np.linalg.norm(u_test, 2, axis=1)
    )

    # Print progress every 100 iterations
    if n % 500 == 0:
        print(f"Iteration: {n} Train_loss:{loss_train}, Test_loss: {loss_test}")

    # Store metrics
    train_err_list.append(err_train)
    test_err_list.append(err_test)
    train_loss_list.append(loss_train)
    test_loss_list.append(loss_test)

    # Increment iteration counter
    n = n + 1
# Out:
# 2026-04-05 14:42:01.962070: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Iteration: 0 Train_loss:1.164702296257019, Test_loss: 0.7112268805503845
# Iteration: 500 Train_loss:0.0036528059281408787, Test_loss: 0.004333720076829195
# Iteration: 1000 Train_loss:0.0006665444234386086, Test_loss: 0.0013702231226488948
# Iteration: 1500 Train_loss:0.0004679509438574314, Test_loss: 0.0009019886492751539
# Iteration: 2000 Train_loss:0.0004140324890613556, Test_loss: 0.0007460119668394327
# Iteration: 2500 Train_loss:0.00040836085099726915, Test_loss: 0.0007952831801958382
# Iteration: 3000 Train_loss:0.0003427915507927537, Test_loss: 0.0005926918238401413
# Iteration: 3500 Train_loss:0.00037830579094588757, Test_loss: 0.0006330169853754342
# Iteration: 4000 Train_loss:0.0003112110716756433, Test_loss: 0.0005067962920293212
# Iteration: 4500 Train_loss:0.0008757939212955534, Test_loss: 0.0006426676991395652
# Iteration: 5000 Train_loss:0.0002736809547059238, Test_loss: 0.0004433854774106294
# Iteration: 5500 Train_loss:0.00021838922111783177, Test_loss: 0.0003966727526858449
# Iteration: 6000 Train_loss:6.023496825946495e-05, Test_loss: 0.00021799727983307093
# Iteration: 6500 Train_loss:3.9374674088321626e-05, Test_loss: 0.00017508120799902827
# Iteration: 7000 Train_loss:0.0005094878724776208, Test_loss: 0.0009822851279750466
# Iteration: 7500 Train_loss:3.318083690828644e-05, Test_loss: 0.00014427583664655685
# Iteration: 8000 Train_loss:3.022974487976171e-05, Test_loss: 0.0001306139020016417
# Iteration: 8500 Train_loss:2.9013017410761677e-05, Test_loss: 0.00012218377378303558
# Iteration: 9000 Train_loss:2.6947298465529457e-05, Test_loss: 0.00011572624498512596
# Iteration: 9500 Train_loss:2.867771399905905e-05, Test_loss: 0.00011452299077063799
# Iteration: 10000 Train_loss:2.4642788048367947e-05, Test_loss: 0.00010756949632195756
# Iteration: 9900 Train_loss:2.9126973458915018e-05, Test_loss: 0.00012926151975989342
# Iteration: 10000 Train_loss:3.273977927165106e-05, Test_loss: 0.00012896307453047484

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec


train_loss = np.array(train_loss_list)
test_loss =  np.array(test_loss_list)
plot_int = 100

ep = np.arange(0,nmax+1,1)
ep = ep[::plot_int]

train_loss_plot = train_loss[::plot_int]
test_loss_plot = train_loss[::plot_int]



gs = gridspec.GridSpec(1,1)
ax = plt.subplot(gs[:, :])
ax.set_xlabel('Epoch')
ax.set_ylabel('MSE')
ax.set_ylim([10**-5, 1])
ax.semilogy(ep, train_loss_plot, '--b', lw=2.0, label="Train")
ax.semilogy(ep, test_loss_plot, '-k', lw=1.0, label="Test")
plt.legend()
plt.savefig("Loss.png", dpi=300)
plt.show()

# %%
####
gs1 = gridspec.GridSpec(1,1)
ax1 = plt.subplot(gs1[:, :])

ax1.plot(x_test, u_test_pred[20, :], '-k', lw=2.0, label="Predicted $u(x)$")

for i in range(10,20):
    ax1.plot(x_test, u_test_pred[i, :], '-k', lw=2.0)

ax1.plot(x_test, u_test[20, :], '--r', lw=2.0, label="Actual $u(x)$")

for i in range(10,20):
    ax1.plot(x_train,u_test[i, :], '--r', lw=2.0)



ax1.set_xlabel('$x$')
ax1.set_ylabel('$u$')
ax1.legend(frameon=True, loc = 'best')
plt.savefig("predicted_and_deeponet.png", dpi=300)
plt.show()

####
gs2 = gridspec.GridSpec(1,1)
ax2 = plt.subplot(gs2[:, :])

ax2.plot(x_test, v_test[20, :], '-g', lw=2.0, label="$v(x)$")
for i in range(10,20):
    ax2.plot(x_test, v_test[i, :], '-g', lw=2.0)

ax2.set_xlabel('$x$')
ax2.set_ylabel('$v(x)$')
ax2.legend(frameon=True, loc = 'best')
plt.savefig("forcing.png", dpi=300)

# %% [markdown]
# ## PI-DeepONet for Antiderivative Operators in TF

# %%
import os
import time
import tensorflow as tf
import numpy as np
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as io
np.random.seed(1234)
import sys

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 


class DNN:
    def __init__(self):
        pass
    #initialization for DNNs
    def hyper_initial(self, layers):
        L = len(layers)
        W = []
        b = []
        for l in range(1, L):
            in_dim = layers[l-1]
            out_dim = layers[l]
            std = np.sqrt(2.0/(in_dim+out_dim))
            weight = tf.Variable(tf.random.truncated_normal(shape=(in_dim, out_dim), stddev = std))
            bias = tf.Variable(tf.random.truncated_normal(shape=(1, out_dim), stddev = std))
            W.append(weight)
            b.append(bias)
        return W, b

    def fnn_B(self, X, W, b):
        A = X
        A = tf.cast(A, dtype=tf.float32)
        L = len(W)
        for i in range(L-1):
            A = tf.nn.relu(tf.add(tf.matmul(A, W[i]), b[i]))
        Y = tf.add(tf.matmul(A, W[-1]), b[-1])
        return Y
    
    def fnn_T(self, X, W, b):
        A = X #2.*(X - Xmin)/(Xmax - Xmin) - 1.0
        A = tf.cast(A, dtype=tf.float32)
        L = len(W)
        for i in range(L-1):
            A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
        Y = tf.add(tf.matmul(A, W[-1]), b[-1])
        return Y
    
    
#Load Training Data
d = np.load("antiderivative_aligned_train.npz", allow_pickle=True)
v_train, x_train, u_train = d["X"][0], d["X"][1], d["y"]


d = np.load("antiderivative_aligned_test.npz", allow_pickle=True)
v_test, x_test, u_test = d["X"][0], d["X"][1], d["y"]

#input dimension for Branch Net
u_dim = 100

#output dimension for Branch and Trunk Net
G_dim = 100

#Branch Net
layers_f = [u_dim] + [40]*4 + [G_dim]

# Trunk dim
x_dim = 1

#Trunk Net
layers_x = [x_dim] + [40]*4 + [G_dim]

model = DNN()

@tf.function()
def train_step(model, W_branch, b_branch, W_trunk, b_trunk, v, x, u, opt):
    train_vars = W_branch + b_branch + W_trunk + b_trunk
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_branch, b_branch, W_trunk, b_trunk, x])
        u_out_branch = model.fnn_B(v, W_branch, b_branch)
        u_out_trunk = model.fnn_T(x, W_trunk, b_trunk)       
        u_pred = tf.einsum('ij,kj->ik', u_out_branch, u_out_trunk)
        loss_data = tf.reduce_mean(tf.square(u_pred - u))        
        loss_phys = 0.0
        #print(tf.shape(v))
        for i in range(0, 10):      
            u_p = u_pred[i]
            u_o = v[i]
            res = tape.gradient(u_p, x)
            loss_phys += tf.reduce_mean(tf.square(res - u_o))
            loss = loss_phys + loss_data
        grads = tape.gradient(loss, train_vars)
        opt.apply_gradients(zip(grads, train_vars))
        return loss_data, u_pred 

def test_step(model, W_branch, b_branch, W_trunk, b_trunk, v, x, u, opt):
    x_test_tf = tf.convert_to_tensor(x, dtype=tf.float32)
    v_test_tf = tf.convert_to_tensor(v, dtype=tf.float32)
    u_test_tf = tf.convert_to_tensor(u, dtype=tf.float32)
    u_out_branch = model.fnn_B(v_test_tf, W_branch, b_branch)
    u_out_trunk = model.fnn_T(x_test_tf, W_trunk, b_trunk)       
    u_pred = tf.einsum('ij,kj->ik', u_out_branch, u_out_trunk)
    loss = tf.reduce_mean(tf.square(u_pred - u))        
    return loss, u_pred 

    
W_branch, b_branch = model.hyper_initial(layers_f)
W_trunk, b_trunk =   model.hyper_initial(layers_x)

n = 0
nmax = 10000
lr = 1e-4
start_time = time.time()
time_step_0 = time.time()
optimizer = tf.optimizers.Adam(learning_rate=lr)
                        
train_err_list = []
test_err_list = []
train_loss_list = []
test_loss_list = []

while n <= nmax:
    x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
    v_train_tf = tf.convert_to_tensor(v_train, dtype=tf.float32)
    u_train_tf = tf.convert_to_tensor(u_train, dtype=tf.float32)
    loss_train, u_train_pred = train_step(model, W_branch, b_branch, W_trunk, \
                                          b_trunk, v_train_tf, x_train_tf, u_train_tf, \
                            optimizer)
    err_train = np.mean(np.linalg.norm(u_train - u_train_pred, 2, axis=1)/\
                np.linalg.norm(u_train , 2, axis=1))
    
    loss_test, u_test_pred = test_step(model, W_branch, b_branch, W_trunk, b_trunk, v_test, x_test, u_test, \
                            optimizer)
    err_test = np.mean(np.linalg.norm(u_test - u_test_pred, 2, axis=1)/\
            np.linalg.norm(u_test , 2, axis=1))
    
    if n % 100 == 0:
        print(f"Iteration: {n} Train_loss:{loss_train}, Test_loss: {loss_test}")
    train_err_list.append(err_train)
    test_err_list.append(err_test)
    train_loss_list.append(loss_train)
    test_loss_list.append(loss_test)     
    n = n + 1
# Out:
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# Iteration: 0 Train_loss:0.3647967576980591, Test_loss: 0.40203890204429626
# Iteration: 100 Train_loss:0.020022425800561905, Test_loss: 0.019341889768838882
# Iteration: 200 Train_loss:0.010449131950736046, Test_loss: 0.010220623575150967
# Iteration: 300 Train_loss:0.00825316458940506, Test_loss: 0.008423537947237492
# Iteration: 400 Train_loss:0.0068852873519063, Test_loss: 0.00726036261767149
# Iteration: 500 Train_loss:0.005405094474554062, Test_loss: 0.006238591857254505
# Iteration: 600 Train_loss:0.0050542401149868965, Test_loss: 0.005798559170216322
# Iteration: 700 Train_loss:0.004836104344576597, Test_loss: 0.00553868105635047
# Iteration: 800 Train_loss:0.004669958725571632, Test_loss: 0.005336014553904533
# Iteration: 900 Train_loss:0.0045580738224089146, Test_loss: 0.005171091295778751
# Iteration: 1000 Train_loss:0.004473668523132801, Test_loss: 0.005056350491940975
# Iteration: 1100 Train_loss:0.004407088737934828, Test_loss: 0.004964787513017654
# Iteration: 1200 Train_loss:0.004350151401013136, Test_loss: 0.004883474670350552
# Iteration: 1300 Train_loss:0.004306119866669178, Test_loss: 0.004815027583390474
# Iteration: 1400 Train_loss:0.0042682429775595665, Test_loss: 0.004759598523378372
# Iteration: 1500 Train_loss:0.00423295795917511, Test_loss: 0.004711852874606848
# Iteration: 1600 Train_loss:0.004203563556075096, Test_loss: 0.004672603216022253
# Iteration: 1700 Train_loss:0.004175521433353424, Test_loss: 0.0046401494182646275
# Iteration: 1800 Train_loss:0.004151489585638046, Test_loss: 0.004610743839293718
# Iteration: 1900 Train_loss:0.00413018511608243, Test_loss: 0.004585271701216698
# Iteration: 2000 Train_loss:0.004109938163310289, Test_loss: 0.004564186092466116
# Iteration: 2100 Train_loss:0.0040909224189817905, Test_loss: 0.0045424397103488445
# Iteration: 2200 Train_loss:0.004070982336997986, Test_loss: 0.004523832816630602
# Iteration: 2300 Train_loss:0.004052064847201109, Test_loss: 0.004505679477006197
# Iteration: 2400 Train_loss:0.0040342966094613075, Test_loss: 0.004487561993300915
# Iteration: 2500 Train_loss:0.004018107429146767, Test_loss: 0.004468599334359169
# Iteration: 2600 Train_loss:0.00400264747440815, Test_loss: 0.004444342106580734
# Iteration: 2700 Train_loss:0.003987413831055164, Test_loss: 0.004426345694810152
# Iteration: 2800 Train_loss:0.0039724791422486305, Test_loss: 0.004408065229654312
# Iteration: 2900 Train_loss:0.003959410823881626, Test_loss: 0.0043945820070803165
# Iteration: 3000 Train_loss:0.003948425408452749, Test_loss: 0.004381959326565266
# Iteration: 3100 Train_loss:0.003938745707273483, Test_loss: 0.004371569957584143
# Iteration: 3200 Train_loss:0.0039296625182032585, Test_loss: 0.004361029714345932
# Iteration: 3300 Train_loss:0.003918747883290052, Test_loss: 0.0043509965762495995
# Iteration: 3400 Train_loss:0.003906597383320332, Test_loss: 0.004337698221206665
# Iteration: 3500 Train_loss:0.0038957977667450905, Test_loss: 0.00432407995685935
# Iteration: 3600 Train_loss:0.003886046353727579, Test_loss: 0.00431192247197032
# Iteration: 3700 Train_loss:0.003876117058098316, Test_loss: 0.004298269748687744
# Iteration: 3800 Train_loss:0.0038635090459138155, Test_loss: 0.004281649831682444
# Iteration: 3900 Train_loss:0.003841057885438204, Test_loss: 0.004254657309502363
# Iteration: 4000 Train_loss:0.0038237946573644876, Test_loss: 0.004240637179464102
# Iteration: 4100 Train_loss:0.0038032373413443565, Test_loss: 0.004224137403070927
# Iteration: 4200 Train_loss:0.003780121449381113, Test_loss: 0.0042034718208014965
# Iteration: 4300 Train_loss:0.0037520441692322493, Test_loss: 0.0041809831745922565
# Iteration: 4400 Train_loss:0.00371936010196805, Test_loss: 0.004161119926720858
# Iteration: 4500 Train_loss:0.003679077373817563, Test_loss: 0.004141715820878744
# Iteration: 4600 Train_loss:0.0036256746388971806, Test_loss: 0.004117263946682215
# Iteration: 4700 Train_loss:0.003566962433978915, Test_loss: 0.004055384546518326
# Iteration: 4800 Train_loss:0.0035015009343624115, Test_loss: 0.004006216302514076
# Iteration: 4900 Train_loss:0.0034056787844747305, Test_loss: 0.003922983538359404
# Iteration: 5000 Train_loss:0.0032938348595052958, Test_loss: 0.0038343160413205624
# Iteration: 5100 Train_loss:0.0031782537698745728, Test_loss: 0.003728002542629838
# Iteration: 5200 Train_loss:0.003066386329010129, Test_loss: 0.003649950260296464
# Iteration: 5300 Train_loss:0.002956127980723977, Test_loss: 0.0035706490743905306
# Iteration: 5400 Train_loss:0.002855669939890504, Test_loss: 0.0034824798349291086
# Iteration: 5500 Train_loss:0.002790922299027443, Test_loss: 0.003414866281673312
# Iteration: 5600 Train_loss:0.002747387159615755, Test_loss: 0.003355409251525998
# Iteration: 5700 Train_loss:0.0027468400076031685, Test_loss: 0.003383288625627756
# Iteration: 5800 Train_loss:0.0026361499913036823, Test_loss: 0.003232524963095784
# Iteration: 5900 Train_loss:0.002597270766273141, Test_loss: 0.0031594643369317055
# Iteration: 6000 Train_loss:0.0025699990801513195, Test_loss: 0.0031026119831949472
# Iteration: 6100 Train_loss:0.0025543624069541693, Test_loss: 0.0030608410015702248
# Iteration: 6200 Train_loss:0.0025372542440891266, Test_loss: 0.0030304351821541786
# Iteration: 6300 Train_loss:0.0025242308620363474, Test_loss: 0.003002897137776017
# Iteration: 6400 Train_loss:0.002514475490897894, Test_loss: 0.0029860271606594324
# Iteration: 6500 Train_loss:0.0024991026148200035, Test_loss: 0.002953177085146308
# Iteration: 6600 Train_loss:0.002499221358448267, Test_loss: 0.0029505786951631308
# Iteration: 6700 Train_loss:0.0024727091658860445, Test_loss: 0.0028984302189201117
# Iteration: 6800 Train_loss:0.0024595013819634914, Test_loss: 0.002876256126910448
# Iteration: 6900 Train_loss:0.002500025322660804, Test_loss: 0.002890300238505006
# Iteration: 7000 Train_loss:0.0024386995937675238, Test_loss: 0.0028441797476261854
# Iteration: 7100 Train_loss:0.0024235504679381847, Test_loss: 0.002821596572175622
# Iteration: 7200 Train_loss:0.0023912223987281322, Test_loss: 0.0027776495553553104
# Iteration: 7300 Train_loss:0.0023701724130660295, Test_loss: 0.0027471038047224283
# Iteration: 7400 Train_loss:0.0023458516225218773, Test_loss: 0.002719694748520851
# Iteration: 7500 Train_loss:0.002317591803148389, Test_loss: 0.00268276478163898
# Iteration: 7600 Train_loss:0.0022865787614136934, Test_loss: 0.0026458981446921825
# Iteration: 7700 Train_loss:0.0022440943866968155, Test_loss: 0.002597818849608302
# Iteration: 7800 Train_loss:0.0021936986595392227, Test_loss: 0.0025409311056137085
# Iteration: 7900 Train_loss:0.002127483021467924, Test_loss: 0.002473409753292799
# Iteration: 8000 Train_loss:0.002052431460469961, Test_loss: 0.0024080548901110888
# Iteration: 8100 Train_loss:0.0019332367228344083, Test_loss: 0.0023505769204348326
# Iteration: 8200 Train_loss:0.0017836092738434672, Test_loss: 0.0022024281788617373
# Iteration: 8300 Train_loss:0.0016045960364863276, Test_loss: 0.0020662331953644753
# Iteration: 8400 Train_loss:0.0013306536711752415, Test_loss: 0.0018489813664928079
# Iteration: 8500 Train_loss:0.0010874532163143158, Test_loss: 0.0016479078913107514
# Iteration: 8600 Train_loss:0.0009730098536238074, Test_loss: 0.0015395967056974769
# Iteration: 8700 Train_loss:0.0009075714042410254, Test_loss: 0.0014674337580800056
# Iteration: 8800 Train_loss:0.0009051800007000566, Test_loss: 0.0014652449171990156
# Iteration: 8900 Train_loss:0.0009040452423505485, Test_loss: 0.0014297683956101537
# Iteration: 9000 Train_loss:0.0008413066971115768, Test_loss: 0.0013715653913095593
# Iteration: 9100 Train_loss:0.0008809072896838188, Test_loss: 0.0013723731972277164
# Iteration: 9200 Train_loss:0.0008159229182638228, Test_loss: 0.0013387274229899049
# Iteration: 9300 Train_loss:0.000810955127235502, Test_loss: 0.0013240687549114227
# Iteration: 9400 Train_loss:0.0007981910603120923, Test_loss: 0.0013087708503007889
# Iteration: 9500 Train_loss:0.0007899320335127413, Test_loss: 0.0012971105752512813
# Iteration: 9600 Train_loss:0.0008017286891117692, Test_loss: 0.0013025576481595635
# Iteration: 9700 Train_loss:0.0007726604235358536, Test_loss: 0.0012777552474290133
# Iteration: 9800 Train_loss:0.0007674226071685553, Test_loss: 0.0012693910393863916
# Iteration: 9900 Train_loss:0.0007592600886709988, Test_loss: 0.0012577340239658952
# Iteration: 10000 Train_loss:0.000753051892388612, Test_loss: 0.001249820226803422

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec


train_loss = np.array(train_loss_list)
test_loss =  np.array(test_loss_list)
plot_int = 1

ep = np.arange(0,nmax+1,1)
ep = ep[::plot_int]

train_loss_plot = train_loss[::plot_int]
test_loss_plot = train_loss[::plot_int]



gs = gridspec.GridSpec(1,1)
ax = plt.subplot(gs[:, :])
ax.set_xlabel('Epoch')
ax.set_ylabel('MSE')
ax.set_ylim([10**-5, 2])
ax.semilogy(ep, train_loss_plot, '--b', lw=2.0, label="Train")
ax.semilogy(ep, test_loss_plot, '-k', lw=1.0, label="Test")
plt.legend()
plt.savefig("Loss.png", dpi=300)
plt.show()

# %% [markdown]
# ## DeepONet for Antiderivative Operators in JAX

# %%
import jax
import numpy as np
import jax.numpy as jnp
import optax
from jax.example_libraries import optimizers
from jax import jit, grad, vmap, value_and_grad
from jax import random
import scipy.io as io
import time
import sys
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec

# %%
import numpy as np
import jax.numpy as jnp
# Load the data and visualize 
d = np.load("antiderivative_train.npz", allow_pickle=True)
v_train, x_train, u_train = jnp.array(d["X"][0]), \
jnp.array(d["X"][1]), jnp.array(d["y"])

d = np.load("antiderivative_test.npz", allow_pickle=True)
v_test, x_test, u_test = jnp.array(d["X"][0]),\
jnp.array(d["X"][1]), jnp.array(d["y"])

####### Row 0: u(t,x) ##################    
gs0 = gridspec.GridSpec(1,1)
ax = plt.subplot(gs0[:, :])
ax.plot(x_train, v_train[10,:], '-k', lw=2.0, label="$v(x)$")
ax.plot(x_train, u_train[10,:], '-b', lw=2.0, label="$u(x)$")
ax.plot(x_train, v_test[100,:], '--k', lw=2.0, label="$v(x)$")
ax.plot(x_train, u_test[100,:], '--b', lw=2.0, label="$u(x)$")
ax.set_xlabel('$x$')
ax.set_ylabel('$u$')
ax.legend(frameon=False, loc = 'best')
ax.set_title('$v \sim \mathcal{GP}(0, cov(x,x))$', fontsize = 10)
plt.savefig("Data.png", dpi=300)
plt.show()
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
key = random.PRNGKey(1234)
initializer = jax.nn.initializers.glorot_normal()
def hyper_initial(layers):
    L = len(layers)
    W = []
    b = []
    for l in range(1, L):
        in_dim = layers[l-1]
        out_dim = layers[l]
        std = np.sqrt(2.0/(in_dim+out_dim))
        weight = initializer(key, (in_dim, out_dim), jnp.float32)*std
        bias = initializer(key, (1, out_dim), jnp.float32)*std
        W.append(weight)
        b.append(bias)
    return W, b
def fnn_B(X, W, b):
    inputs = X
    L = len(W)
    for i in range(L-1):
        outputs = jnp.dot(inputs, W[i]) + b[i]
        inputs = jnp.tanh(outputs)  
    Y = jnp.dot(inputs, W[-1]) + b[-1]     
    return Y

def fnn_T(X, W, b):
    inputs = X
    L = len(W)
    for i in range(L-1):
        outputs = jnp.dot(inputs, W[i]) + b[i]
        inputs = jnp.tanh(outputs)  # inputs to the next layer
    Y = jnp.dot(inputs, W[-1]) + b[-1]     
    return Y


def predict(params, data):
    W_branch, b_branch, W_trunk, b_trunk = params
    v, x = data
    u_out_branch = fnn_B(v, W_branch, b_branch) # predict on branch
    u_out_trunk = fnn_T(x, W_trunk, b_trunk) # predict on trunk
    u_pred = jnp.einsum('ik,jk->ik',u_out_branch, u_out_trunk) # matmul
    return u_pred

def loss(params, data, u):
    u_preds = predict(params, data)
    # print(u_preds)
    mse = jnp.mean(jnp.sum((u_preds - u)**2, axis = 1)) 
    # print(mse)
    return mse

@jit
def update(params, data, u, opt_state):
    """ Compute the gradient for a batch and update the parameters """
    value, grads = value_and_grad(loss)(params, data, u)
    opt_state = opt_update(0, grads, opt_state)
    return get_params(opt_state), opt_state, value


#input dimension for Branch Net
u_dim = 100
#output dimension for Branch and Trunk Net
G_dim = 100
#Branch Net
layers_f = [u_dim] + [40]*2 + [G_dim]
# Trunk dim
x_dim = 1
#Trunk Net
layers_x = [x_dim] + [40]*2 + [G_dim]
W_branch, b_branch = hyper_initial(layers_f)
W_trunk, b_trunk =   hyper_initial(layers_x)
# Defining an optimizer in Jax
num_epochs = 10000
lr = 5e-4
opt_init, opt_update, get_params = optimizers.adam(lr)
opt_state = opt_init([W_branch, b_branch, W_trunk, b_trunk])
params = get_params(opt_state)
train_loss, test_loss = [], []

start_time = time.time()

for epoch in range(num_epochs):
    params, opt_state, loss_val = update(params, [v_train, x_train], u_train, opt_state)
    train_loss.append(loss_val)
    if epoch % 100 ==0:
        epoch_time = time.time() - start_time
        u_train_pred = predict(params, [v_train, x_train])
        err_train = jnp.mean(jnp.linalg.norm(u_train - u_train_pred, 2, axis=1)/\
                             np.linalg.norm(u_train , 2, axis=1))
        u_test_pred = predict(params, [v_test, x_test])
        err_test = jnp.mean(jnp.linalg.norm(u_test - u_test_pred, 2, axis=1)/\
                            np.linalg.norm(u_test , 2, axis=1))
        test_loss_val = loss(params, [v_test, x_test], u_test)
        test_loss.append(test_loss_val)
        print("Epoch {} | T: {:0.6f} | Train MSE: {:0.4f} | \
        Test MSE: {:0.4f} | Train L2: {:0.4f} | Test L2: {:0.4f}"\
              .format(epoch, epoch_time, loss_val, test_loss_val, err_train, err_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 key = random.PRNGKey(1234)
#       2 initializer = jax.nn.initializers.glorot_normal()
#       3 def hyper_initial(layers):
#
# NameError: name 'random' is not defined

# %%
train_loss = np.array(train_loss)
test_loss =  np.array(test_loss)
plot_int = 100

ep = np.arange(0,num_epochs,1)
ep = ep[::plot_int]

train_loss_plot = train_loss[::plot_int]
test_loss_plot = train_loss[::plot_int]



gs = gridspec.GridSpec(1,1)
ax = plt.subplot(gs[:, :])
ax.set_xlabel('Epoch')
ax.set_ylabel('MSE')
#ax.set_ylim([10**-5, 1])
ax.semilogy(ep, train_loss_plot, '--b', lw=2.0, label="Train")
ax.semilogy(ep, test_loss_plot, '-k', lw=1.0, label="Test")
plt.legend()
plt.savefig("Loss.png", dpi=300)
plt.show()



pred = predict(params, [v_train, x_train])
u_test_pred = predict(params, [v_test, x_test])

############################
gs1 = gridspec.GridSpec(1,1)
ax1 = plt.subplot(gs1[:, :])

ax1.plot(x_test, u_test_pred[20, :], '-k', lw=2.0, label="Predicted $u(x)$")

for i in range(10,20):
    ax1.plot(x_test, u_test_pred[i, :], '-k', lw=2.0)

ax1.plot(x_test, u_test[20, :], '--r', lw=2.0, label="Actual $u(x)$")

for i in range(10,20):
    ax1.plot(x_train,u_test[i, :], '--r', lw=2.0)



ax1.set_xlabel('$x$')
ax1.set_ylabel('$u$')
ax1.legend(frameon=True, loc = 'best')
plt.savefig("predicted_and_deeponet.png", dpi=300)
plt.show()

####
gs2 = gridspec.GridSpec(1,1)
ax2 = plt.subplot(gs2[:, :])

ax2.plot(x_test, v_test[20, :], '-g', lw=2.0, label="$v(x)$")
for i in range(10,20):
    ax2.plot(x_test, v_test[i, :], '-g', lw=2.0)

ax2.set_xlabel('$x$')
ax2.set_ylabel('$v(x)$')
ax2.legend(frameon=True, loc = 'best')
plt.savefig("forcing.png", dpi=300)

# %% [markdown]
# ## Fourier Neural Operator (FNO) for Burgers Equation

# %%
# ============================================================
# Fourier Neural Operator (FNO) for 1D Burgers equation
# Original code note in file: "Z Li (2020) is original code"
# Heavily Modified and commented version
# ============================================================

# -----------------------------
# Standard numerical libraries
# -----------------------------
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# PyTorch core
# -----------------------------
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter

# -----------------------------
# Utility imports
# -----------------------------
import operator
from functools import reduce
from functools import partial
from timeit import default_timer

# Custom helper functions/classes.
# Likely includes:
# - MatReader: for loading .mat datasets
# - count_params: for parameter counting
# - LpLoss: relative Lp loss used in operator learning
from op_utilities import *

# Adam optimizer
from torch.optim import Adam

# -----------------------------
# Fix random seeds for reproducibility
# -----------------------------
torch.manual_seed(0)
np.random.seed(0)


# ============================================================
# Spectral convolution layer in 1D
# ============================================================
# This is the key building block of the FNO.
# Instead of doing a local convolution in physical space,
# it:
#   1. transforms the signal to Fourier space,
#   2. multiplies only a limited number of low-frequency modes,
#   3. transforms back to physical space.
#
# This lets the network learn global integral operators efficiently.
# ============================================================
class SpectralConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, modes1):
        super(SpectralConv1d, self).__init__()

        # Number of input channels/features
        self.in_channels = in_channels

        # Number of output channels/features
        self.out_channels = out_channels

        # Number of Fourier modes to keep and learn.
        # For a real 1D FFT, the total number of available frequencies
        # after rfft is floor(N/2)+1.
        # We only learn the first "modes1" low-frequency modes.
        self.modes1 = modes1

        # Scaling factor for weight initialization.
        # Keeps initial values small and stable.
        self.scale = (1 / (in_channels * out_channels))

        # Learnable complex-valued weights in Fourier space.
        # Shape:
        #   (in_channels, out_channels, modes1)
        #
        # Each retained Fourier mode gets its own learned transformation
        # from input channels to output channels.
        self.weights1 = nn.Parameter(
            self.scale * torch.rand(
                in_channels,
                out_channels,
                self.modes1,
                dtype=torch.cfloat
            )
        )

    # --------------------------------------------------------
    # Complex multiplication in Fourier space
    # --------------------------------------------------------
    # input shape:   (batch, in_channel, x_modes)
    # weights shape: (in_channel, out_channel, x_modes)
    # output shape:  (batch, out_channel, x_modes)
    #
    # This mixes channels independently at each retained frequency.
    # --------------------------------------------------------
    def compl_mul1d(self, input, weights):
        return torch.einsum("bix,iox->box", input, weights)

    # --------------------------------------------------------
    # Forward pass of spectral convolution
    # --------------------------------------------------------
    def forward(self, x):
        # x shape:
        #   (batch, in_channels, spatial_points)
        batchsize = x.shape[0]

        # Compute 1D real FFT along the spatial dimension.
        # Output is complex-valued and only contains nonnegative frequencies.
        # Shape:
        #   (batch, in_channels, N//2 + 1)
        x_ft = torch.fft.rfft(x)

        # Prepare output tensor in Fourier space.
        # It has the frequency resolution corresponding to rfft output.
        out_ft = torch.zeros(
            batchsize,
            self.out_channels,
            x.size(-1)//2 + 1,
            device=x.device,
            dtype=torch.cfloat
        )

        # Only the first "modes1" Fourier modes are learned/transformed.
        # Higher frequencies are left as zero.
        #
        # This is a low-pass spectral operator:
        # the model focuses on dominant, smooth structures.
        out_ft[:, :, :self.modes1] = self.compl_mul1d(
            x_ft[:, :, :self.modes1],
            self.weights1
        )

        # Transform back to physical space using inverse real FFT.
        # Result shape:
        #   (batch, out_channels, spatial_points)
        x = torch.fft.irfft(out_ft, n=x.size(-1))
        return x


# ============================================================
# 1D Fourier Neural Operator model
# ============================================================
# This network learns a mapping:
#   input function a(x) --> output function u(x)
#
# For Burgers equation, a(x) may be an initial condition or coefficient,
# and u(x) is the target solution/function.
#
# Structure:
#   1. Lift input to higher-dimensional feature space
#   2. Apply several Fourier layers + local skip layers
#   3. Project back to scalar output
# ============================================================
class FNO1d(nn.Module):
    def __init__(self, modes, width):
        super(FNO1d, self).__init__()

        # Number of retained Fourier modes in each spectral layer
        self.modes1 = modes

        # Width of hidden feature channels
        self.width = width

        # Optional padding value.
        # In some FNO implementations, padding is used when data is not periodic.
        # Here it is defined but not actually used in forward().
        self.padding = 2

        # First linear layer ("lifting layer")
        # Input channel dimension is 2:
        #   - the field value a(x)
        #   - the coordinate x itself
        #
        # So each spatial point has a 2D feature vector: [a(x), x]
        self.fc0 = nn.Linear(2, self.width)

        # Four spectral convolution layers
        self.conv0 = SpectralConv1d(self.width, self.width, self.modes1)
        self.conv1 = SpectralConv1d(self.width, self.width, self.modes1)
        self.conv2 = SpectralConv1d(self.width, self.width, self.modes1)
        self.conv3 = SpectralConv1d(self.width, self.width, self.modes1)

        # Four 1x1 convolutions
        # These act like pointwise linear transformations across channels.
        # They provide a local path that complements the global Fourier path.
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)
        self.w2 = nn.Conv1d(self.width, self.width, 1)
        self.w3 = nn.Conv1d(self.width, self.width, 1)

        # Projection head:
        # hidden features -> 128 -> scalar output at each spatial location
        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    # --------------------------------------------------------
    # Forward pass
    # --------------------------------------------------------
    def forward(self, x):
        # Input x shape:
        #   (batch, spatial_points, 1)
        # where the last dimension is the scalar field a(x)

        # Build coordinate grid and concatenate it to the input.
        # This makes the model coordinate-aware.
        grid = self.get_grid(x.shape, x.device)

        # Concatenate along feature dimension:
        # from (batch, s, 1) to (batch, s, 2)
        x = torch.cat((x, grid), dim=-1)

        # Lift input features into higher-dimensional channel space
        # Shape becomes:
        #   (batch, s, width)
        x = self.fc0(x)

        # Rearrange for Conv1d / spectral conv format:
        #   (batch, channels, spatial_points)
        x = x.permute(0, 2, 1)

        # -------------------------
        # Fourier block 1
        # -------------------------
        # x1: global spectral operator
        x1 = self.conv0(x)

        # x2: local pointwise linear operator
        x2 = self.w0(x)

        # Combine global and local information
        x = x1 + x2

        # Nonlinear activation
        x = F.gelu(x)

        # -------------------------
        # Fourier block 2
        # -------------------------
        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        # -------------------------
        # Fourier block 3
        # -------------------------
        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        # -------------------------
        # Fourier block 4
        # -------------------------
        # Final block has no GELU after it in this implementation
        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        # Convert back to:
        #   (batch, spatial_points, channels)
        x = x.permute(0, 2, 1)

        # Projection to lower-dimensional hidden space
        x = self.fc1(x)
        x = F.gelu(x)

        # Final scalar output at each point
        # Output shape:
        #   (batch, spatial_points, 1)
        x = self.fc2(x)
        return x

    # --------------------------------------------------------
    # Create spatial coordinate grid
    # --------------------------------------------------------
    # This gives each spatial point its x-location in [0,1].
    # The grid is concatenated with the input function values.
    #
    # shape is expected to look like:
    #   (batchsize, size_x, channels)
    # --------------------------------------------------------
    def get_grid(self, shape, device):
        batchsize, size_x = shape[0], shape[1]

        # Create 1D coordinate values from 0 to 1
        gridx = torch.tensor(np.linspace(0, 1, size_x), dtype=torch.float)

        # Reshape to (1, size_x, 1) and repeat for the whole batch
        gridx = gridx.reshape(1, size_x, 1).repeat([batchsize, 1, 1])

        return gridx.to(device)


# ============================================================
# Configuration / hyperparameters
# ============================================================

# Number of training samples
ntrain = 1000

# Number of test samples
ntest = 100

# Subsampling rate:
# original resolution is downsampled by factor 2^3 = 8
sub = 2**3

# Effective spatial grid size after subsampling
# Original size appears to be 2^13 = 8192
# After downsampling: 8192 / 8 = 1024
h = 2**13 // sub

# Spatial resolution used by the model
s = h

# Batch size for training/testing
batch_size = 20

# Initial learning rate
learning_rate = 0.001

# Number of training epochs
epochs = 500

# Learning-rate scheduler settings:
# every 50 epochs, lr is multiplied by gamma = 0.5
step_size = 50
gamma = 0.5

# Number of retained Fourier modes
modes = 16

# Width of hidden channel dimension
width = 64


# ============================================================
# Data loading
# ============================================================

# Load Burgers equation dataset from .mat file
# Assumes:
#   field 'a' = input functions
#   field 'u' = target solution functions
dataloader = MatReader('/Users/raj/Desktop/burgers_data_R10.mat')

# Read and subsample input/output fields
# [:, ::sub] means take every "sub" spatial point
x_data = dataloader.read_field('a')[:, ::sub]
y_data = dataloader.read_field('u')[:, ::sub]

# Split into training and test sets
x_train = x_data[:ntrain, :]
y_train = y_data[:ntrain, :]
x_test = x_data[-ntest:, :]
y_test = y_data[-ntest:, :]

# Reshape inputs to include explicit feature dimension = 1
# Input shape expected by the model:
#   (num_samples, spatial_points, 1)
x_train = x_train.reshape(ntrain, s, 1)
x_test = x_test.reshape(ntest, s, 1)

# Build PyTorch DataLoaders
# Training loader shuffles samples
train_loader = torch.utils.data.DataLoader(
    torch.utils.data.TensorDataset(x_train, y_train),
    batch_size=batch_size,
    shuffle=True
)

# Test loader does not shuffle
test_loader = torch.utils.data.DataLoader(
    torch.utils.data.TensorDataset(x_test, y_test),
    batch_size=batch_size,
    shuffle=False
)


# ============================================================
# Model creation
# ============================================================

# Instantiate FNO model
model = FNO1d(modes, width)

# Print total number of trainable parameters
print(f"Number of Parameters: {count_params(model)}")


# ============================================================
# Training setup
# ============================================================

# Adam optimizer with L2 weight decay
optimizer = Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)

# Step learning-rate scheduler
scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=step_size,
    gamma=gamma
)

# Relative Lp loss object
# In FNO/operator-learning code, this is often preferred over plain MSE
# because it measures relative function error
myloss = LpLoss(size_average=False)


# ============================================================
# Training loop
# ============================================================
for ep in range(epochs):
    # Switch model to training mode
    model.train()

    # Start timing this epoch
    t1 = default_timer()

    # Accumulators for metrics
    train_mse = 0
    train_l2 = 0

    # Loop over training mini-batches
    for x, y in train_loader:
        # x shape: (batch_size, s, 1)
        # y shape: (batch_size, s)

        # Clear previous gradients
        optimizer.zero_grad()

        # Forward pass
        out = model(x)

        # out shape is likely (batch_size, s, 1)
        # reshape to compare with y shape (batch_size, s)
        mse = F.mse_loss(
            out.view(batch_size, -1),
            y.view(batch_size, -1),
            reduction='mean'
        )

        # Relative L2 / Lp-type loss
        l2 = myloss(
            out.view(batch_size, -1),
            y.view(batch_size, -1)
        )

        # Backpropagate using the relative L2 loss, not MSE
        # This means optimization is driven by operator/function error
        l2.backward()

        # Update parameters
        optimizer.step()

        # Accumulate metrics
        train_mse += mse.item()
        train_l2 += l2.item()

    # Update learning rate after each epoch
    scheduler.step()

    # --------------------------------------------------------
    # Evaluation on test set
    # --------------------------------------------------------
    model.eval()
    test_l2 = 0.0

    with torch.no_grad():
        for x, y in test_loader:
            out = model(x)

            test_l2 += myloss(
                out.view(batch_size, -1),
                y.view(batch_size, -1)
            ).item()

    # Average metrics
    train_mse /= len(train_loader)   # average batch MSE
    train_l2 /= ntrain               # normalize by number of train samples
    test_l2 /= ntest                 # normalize by number of test samples

    # End timing
    t2 = default_timer()

    # Print epoch summary
    print(
        f"Epoch: {ep}, Epoch Time: {t2-t1}, "
        f"Train MSE_Error: {train_mse}, "
        f"Train_L2_Error :{train_l2} "
        f"Test L2 Error, {test_l2}"
    )


# ============================================================
# Optional save
# ============================================================
# torch.save(model, 'model/ns_fourier_burgers')


# ============================================================
# Prediction on the full test set, one sample at a time
# ============================================================

# Allocate tensor to store predictions
# Same shape as y_test
pred = torch.zeros(y_test.shape)

# Index for filling pred row by row
index = 0

# Rebuild test loader with batch_size=1 for samplewise prediction
test_loader = torch.utils.data.DataLoader(
    torch.utils.data.TensorDataset(x_test, y_test),
    batch_size=1,
    shuffle=False
)

with torch.no_grad():
    for x, y in test_loader:
        # Reset per-sample test loss accumulator
        test_l2 = 0

        # Forward pass for one sample
        out = model(x).view(-1)

        # Store prediction
        pred[index] = out

        # Compute relative loss for this one sample
        test_l2 += myloss(out.view(1, -1), y.view(1, -1)).item()

        # Move to next test sample
        index = index + 1
# Out:
# Number of Parameters: 549569
# Epoch: 0, Epoch Time: 13.069419691999883, Train MSE_Error: 0.05239602538873442, Train_L2_Error :0.31149250411987306 Test L2 Error, 0.05157776832580566
# Epoch: 1, Epoch Time: 14.409576306999952, Train MSE_Error: 0.0009731728018959984, Train_L2_Error :0.04498428481817245 Test L2 Error, 0.031348470449447635
# Epoch: 2, Epoch Time: 13.144941317999837, Train MSE_Error: 0.0004834700755600352, Train_L2_Error :0.03169135719537735 Test L2 Error, 0.03782920241355896
# Epoch: 3, Epoch Time: 12.743258126, Train MSE_Error: 0.0004273433734488208, Train_L2_Error :0.033200765132904056 Test L2 Error, 0.022788591980934143
# Epoch: 4, Epoch Time: 12.177860105000036, Train MSE_Error: 0.00022103046758275012, Train_L2_Error :0.020983734369277952 Test L2 Error, 0.01757157266139984
# Epoch: 5, Epoch Time: 12.213924988000144, Train MSE_Error: 0.0002444037765963003, Train_L2_Error :0.025850333005189897 Test L2 Error, 0.02444742828607559
# Epoch: 6, Epoch Time: 12.21371751300012, Train MSE_Error: 0.0002455169361928711, Train_L2_Error :0.025667729914188385 Test L2 Error, 0.029278644919395448
# Epoch: 7, Epoch Time: 12.257740224999907, Train MSE_Error: 0.00024787933103652903, Train_L2_Error :0.027567517071962356 Test L2 Error, 0.024837676286697388
# Epoch: 8, Epoch Time: 12.353233397999702, Train MSE_Error: 0.0001469373171494226, Train_L2_Error :0.019916150093078615 Test L2 Error, 0.024577681720256806
# Epoch: 9, Epoch Time: 11.795781119999901, Train MSE_Error: 0.00022865745922899804, Train_L2_Error :0.028008759588003158 Test L2 Error, 0.025281098186969757
# Epoch: 10, Epoch Time: 12.25665095300019, Train MSE_Error: 0.0002543410709768068, Train_L2_Error :0.029494114547967912 Test L2 Error, 0.030670825242996216
# Epoch: 11, Epoch Time: 12.261032636999971, Train MSE_Error: 0.00016445860794192413, Train_L2_Error :0.022437927544116974 Test L2 Error, 0.024015679955482483
# Epoch: 12, Epoch Time: 12.523595732000103, Train MSE_Error: 0.00020290956046665088, Train_L2_Error :0.02662603749334812 Test L2 Error, 0.022927119731903076
# Epoch: 13, Epoch Time: 12.243603816999894, Train MSE_Error: 0.00019123977072013076, Train_L2_Error :0.026064020931720732 Test L2 Error, 0.0385807067155838
# Epoch: 14, Epoch Time: 12.21490802199969, Train MSE_Error: 0.00019187797108315862, Train_L2_Error :0.02586305072903633 Test L2 Error, 0.028903856873512268
# Epoch: 15, Epoch Time: 12.253044752000278, Train MSE_Error: 0.00017961007564736063, Train_L2_Error :0.02446073865890503 Test L2 Error, 0.0161782106757164
# Epoch: 16, Epoch Time: 12.231840015000216, Train MSE_Error: 0.0001603220996184973, Train_L2_Error :0.023663592740893365 Test L2 Error, 0.01622899979352951
# Epoch: 17, Epoch Time: 12.240501411999958, Train MSE_Error: 8.041363154916326e-05, Train_L2_Error :0.016012997657060622 Test L2 Error, 0.01216804176568985
# Epoch: 18, Epoch Time: 12.545913220999864, Train MSE_Error: 9.074803791008889e-05, Train_L2_Error :0.01661705768108368 Test L2 Error, 0.01581839382648468
# Epoch: 19, Epoch Time: 12.49958378600013, Train MSE_Error: 7.351133132033283e-05, Train_L2_Error :0.01481062711775303 Test L2 Error, 0.010679125934839249
# Epoch: 20, Epoch Time: 12.529446309999912, Train MSE_Error: 0.0001345388772097067, Train_L2_Error :0.020531987726688385 Test L2 Error, 0.025811225175857544
# Epoch: 21, Epoch Time: 12.494064077000075, Train MSE_Error: 0.00013315161813807209, Train_L2_Error :0.02147066155076027 Test L2 Error, 0.014424937963485717
# Epoch: 22, Epoch Time: 13.463982361000035, Train MSE_Error: 0.0001618873595725745, Train_L2_Error :0.023704948484897615 Test L2 Error, 0.023008562326431274
# Epoch: 23, Epoch Time: 13.234577856000215, Train MSE_Error: 0.0001514919657347491, Train_L2_Error :0.02329626278579235 Test L2 Error, 0.02606726288795471
# Epoch: 24, Epoch Time: 12.397845851000056, Train MSE_Error: 0.0001459767004052992, Train_L2_Error :0.02220319400727749 Test L2 Error, 0.03265743970870972
# Epoch: 25, Epoch Time: 12.14742199200009, Train MSE_Error: 0.0001590844317252049, Train_L2_Error :0.023198017477989198 Test L2 Error, 0.017884041368961334
# Epoch: 26, Epoch Time: 12.788996516000225, Train MSE_Error: 0.00013648168442159658, Train_L2_Error :0.021999227061867715 Test L2 Error, 0.015491911470890045
# Epoch: 27, Epoch Time: 13.05791674000011, Train MSE_Error: 9.684681113867554e-05, Train_L2_Error :0.01774507863819599 Test L2 Error, 0.02266891598701477
# Epoch: 28, Epoch Time: 12.839705756999592, Train MSE_Error: 0.00012674685880483593, Train_L2_Error :0.02138727566599846 Test L2 Error, 0.021851610839366913
# Epoch: 29, Epoch Time: 12.884090939000089, Train MSE_Error: 0.00014445025557506595, Train_L2_Error :0.02206156773865223 Test L2 Error, 0.028819127678871154
# Epoch: 30, Epoch Time: 12.93246642900067, Train MSE_Error: 0.00011863333314977353, Train_L2_Error :0.019877986162900926 Test L2 Error, 0.019677857756614684
# Epoch: 31, Epoch Time: 13.037377290000222, Train MSE_Error: 0.00011319063920382177, Train_L2_Error :0.02015000356733799 Test L2 Error, 0.010284516513347625
# Epoch: 32, Epoch Time: 13.075159615000302, Train MSE_Error: 7.624879041031818e-05, Train_L2_Error :0.016061616703867913 Test L2 Error, 0.011957345455884933
# Epoch: 33, Epoch Time: 13.097724027999902, Train MSE_Error: 9.409561745997052e-05, Train_L2_Error :0.017425062835216523 Test L2 Error, 0.011709754019975663
# Epoch: 34, Epoch Time: 12.726888002000123, Train MSE_Error: 8.115621471006306e-05, Train_L2_Error :0.015819748923182487 Test L2 Error, 0.022479287683963775
# Epoch: 35, Epoch Time: 13.156281372000194, Train MSE_Error: 0.00012378241186524974, Train_L2_Error :0.02079470784962177 Test L2 Error, 0.014306093454360963
# Epoch: 36, Epoch Time: 13.41719230400031, Train MSE_Error: 0.00011655280834020231, Train_L2_Error :0.019960274502635003 Test L2 Error, 0.015499157011508941
# Epoch: 37, Epoch Time: 12.946086145000663, Train MSE_Error: 5.605781952908728e-05, Train_L2_Error :0.013740786656737327 Test L2 Error, 0.016647928059101105
# Epoch: 38, Epoch Time: 12.989107162000437, Train MSE_Error: 9.05587023953558e-05, Train_L2_Error :0.017716191291809083 Test L2 Error, 0.02564504563808441
# Epoch: 39, Epoch Time: 13.297378526999637, Train MSE_Error: 0.00013605048501631246, Train_L2_Error :0.021978833749890327 Test L2 Error, 0.02369877487421036
# Epoch: 40, Epoch Time: 11.90805037500013, Train MSE_Error: 5.143781912920531e-05, Train_L2_Error :0.012973354831337928 Test L2 Error, 0.010005918890237808
# Epoch: 41, Epoch Time: 12.365791256999728, Train MSE_Error: 0.00010701825784053653, Train_L2_Error :0.019967410773038863 Test L2 Error, 0.02197005420923233
# Epoch: 42, Epoch Time: 12.471258998999474, Train MSE_Error: 6.11396111708018e-05, Train_L2_Error :0.01466725128889084 Test L2 Error, 0.013673948049545288
# Epoch: 43, Epoch Time: 12.696915863999493, Train MSE_Error: 0.00011385309935576515, Train_L2_Error :0.01985957582294941 Test L2 Error, 0.02389900356531143
# Epoch: 44, Epoch Time: 12.678981542000656, Train MSE_Error: 8.719206203750218e-05, Train_L2_Error :0.017400131583213806 Test L2 Error, 0.012250983417034149
# Epoch: 45, Epoch Time: 12.551019685000028, Train MSE_Error: 6.479634477727813e-05, Train_L2_Error :0.014767277494072913 Test L2 Error, 0.01550915390253067
# Epoch: 46, Epoch Time: 12.516068512000857, Train MSE_Error: 7.142364205719786e-05, Train_L2_Error :0.01608598293364048 Test L2 Error, 0.013434078097343444
# Epoch: 47, Epoch Time: 12.07199763800054, Train MSE_Error: 0.00011984818687778898, Train_L2_Error :0.020879603922367096 Test L2 Error, 0.038071203827857975
# Epoch: 48, Epoch Time: 12.420676306000132, Train MSE_Error: 0.00018476971319614677, Train_L2_Error :0.026459114760160447 Test L2 Error, 0.01587888181209564
# Epoch: 49, Epoch Time: 12.242645997999716, Train MSE_Error: 7.098877986209118e-05, Train_L2_Error :0.015236066028475761 Test L2 Error, 0.016573750972747804
# Epoch: 50, Epoch Time: 12.625948528000663, Train MSE_Error: 3.183109305609832e-05, Train_L2_Error :0.00996834471821785 Test L2 Error, 0.008611215949058533
# Epoch: 51, Epoch Time: 12.937304271000357, Train MSE_Error: 3.080450513152755e-05, Train_L2_Error :0.010111843392252922 Test L2 Error, 0.008540922701358795
# Epoch: 52, Epoch Time: 12.783291889999418, Train MSE_Error: 2.4135936091624898e-05, Train_L2_Error :0.008446554712951183 Test L2 Error, 0.007075996845960617
# Epoch: 53, Epoch Time: 12.86677858099938, Train MSE_Error: 2.912101426773006e-05, Train_L2_Error :0.009612860403954983 Test L2 Error, 0.007484653443098069
# Epoch: 54, Epoch Time: 12.595030872999814, Train MSE_Error: 2.8901381829200544e-05, Train_L2_Error :0.010068923689424992 Test L2 Error, 0.011214028000831605
# Epoch: 55, Epoch Time: 12.69550300499941, Train MSE_Error: 2.0859683281742037e-05, Train_L2_Error :0.007623830482363701 Test L2 Error, 0.008929849863052368
# Epoch: 56, Epoch Time: 12.932247935000305, Train MSE_Error: 1.3325287245606887e-05, Train_L2_Error :0.006096615493297577 Test L2 Error, 0.005614104121923447
# Epoch: 57, Epoch Time: 13.10883137699966, Train MSE_Error: 1.977918414013402e-05, Train_L2_Error :0.007786370575428009 Test L2 Error, 0.01432188183069229
# Epoch: 58, Epoch Time: 13.164012000000184, Train MSE_Error: 2.3510191140303506e-05, Train_L2_Error :0.0086026471555233 Test L2 Error, 0.006415299251675606
# Epoch: 59, Epoch Time: 13.277056144000198, Train MSE_Error: 3.096892607572954e-05, Train_L2_Error :0.010633186802268029 Test L2 Error, 0.011890804767608643
# Epoch: 60, Epoch Time: 13.219562893999864, Train MSE_Error: 2.9682922668143875e-05, Train_L2_Error :0.010251023113727569 Test L2 Error, 0.0055563785135746
# Epoch: 61, Epoch Time: 13.275773770999876, Train MSE_Error: 2.643481787345081e-05, Train_L2_Error :0.00952690178900957 Test L2 Error, 0.009555713683366775
# Epoch: 62, Epoch Time: 13.020491096999649, Train MSE_Error: 2.8274540482016165e-05, Train_L2_Error :0.010047303669154644 Test L2 Error, 0.007062553986907005
# Epoch: 63, Epoch Time: 12.367989270999715, Train MSE_Error: 1.5322265317081473e-05, Train_L2_Error :0.0066828767210245135 Test L2 Error, 0.00825015351176262
# Epoch: 64, Epoch Time: 12.270457137999983, Train MSE_Error: 2.4483280512868077e-05, Train_L2_Error :0.008823197402060032 Test L2 Error, 0.009706528782844543
# Epoch: 65, Epoch Time: 12.442658506999578, Train MSE_Error: 1.9137296367262023e-05, Train_L2_Error :0.00758713211864233 Test L2 Error, 0.013220221400260926
# Epoch: 66, Epoch Time: 12.268350285999986, Train MSE_Error: 3.147086903481977e-05, Train_L2_Error :0.010483620420098304 Test L2 Error, 0.008745642602443695
# Epoch: 67, Epoch Time: 12.806492130000152, Train MSE_Error: 3.110342464424321e-05, Train_L2_Error :0.010601385287940503 Test L2 Error, 0.007182981371879577
# Epoch: 68, Epoch Time: 12.669299504999799, Train MSE_Error: 1.2435812250259914e-05, Train_L2_Error :0.006340082734823227 Test L2 Error, 0.007096600979566574
# Epoch: 69, Epoch Time: 12.634368099999847, Train MSE_Error: 2.0981678962925797e-05, Train_L2_Error :0.00800868610292673 Test L2 Error, 0.008297779709100723
# Epoch: 70, Epoch Time: 12.698159121000572, Train MSE_Error: 1.2509714865700516e-05, Train_L2_Error :0.006140235595405102 Test L2 Error, 0.008100429326295852
# Epoch: 71, Epoch Time: 12.178939612999784, Train MSE_Error: 2.430545719107613e-05, Train_L2_Error :0.008940395705401897 Test L2 Error, 0.00495966799557209
# Epoch: 72, Epoch Time: 12.854042491000655, Train MSE_Error: 2.8494950729509583e-05, Train_L2_Error :0.0101725148037076 Test L2 Error, 0.007838701754808426
# Epoch: 73, Epoch Time: 12.542708007000329, Train MSE_Error: 2.8599371426025755e-05, Train_L2_Error :0.00972001890093088 Test L2 Error, 0.00785170778632164
# Epoch: 74, Epoch Time: 13.0076892699999, Train MSE_Error: 2.4141212470567553e-05, Train_L2_Error :0.009132657498121262 Test L2 Error, 0.00838737353682518
# Epoch: 75, Epoch Time: 12.404593777000628, Train MSE_Error: 2.4464807920594468e-05, Train_L2_Error :0.009195100151002406 Test L2 Error, 0.007840092033147813
# Epoch: 76, Epoch Time: 12.466457143000298, Train MSE_Error: 2.997458405843645e-05, Train_L2_Error :0.0105781187787652 Test L2 Error, 0.012913234978914261
# Epoch: 77, Epoch Time: 12.738994762999937, Train MSE_Error: 2.7566899261728396e-05, Train_L2_Error :0.010139630302786827 Test L2 Error, 0.007059524580836296
# Epoch: 78, Epoch Time: 13.090355141000146, Train MSE_Error: 1.3145133625585003e-05, Train_L2_Error :0.00672284672409296 Test L2 Error, 0.005221320614218712
# Epoch: 79, Epoch Time: 13.035771021000073, Train MSE_Error: 1.0305268610864004e-05, Train_L2_Error :0.0056803647503256794 Test L2 Error, 0.005364984571933747
# Epoch: 80, Epoch Time: 12.871880599000178, Train MSE_Error: 1.771402875874628e-05, Train_L2_Error :0.006836807660758495 Test L2 Error, 0.00822853460907936
# Epoch: 81, Epoch Time: 12.831415871999525, Train MSE_Error: 1.3862014225196617e-05, Train_L2_Error :0.0064987817928195 Test L2 Error, 0.005989162027835846
# Epoch: 82, Epoch Time: 13.433751100000336, Train MSE_Error: 1.94818282398046e-05, Train_L2_Error :0.008104491479694843 Test L2 Error, 0.00968921646475792
# Epoch: 83, Epoch Time: 12.400936627999727, Train MSE_Error: 2.4867611682566348e-05, Train_L2_Error :0.008985738970339299 Test L2 Error, 0.010048915147781372
# Epoch: 84, Epoch Time: 12.45311753399983, Train MSE_Error: 2.6055202251882292e-05, Train_L2_Error :0.010158717229962349 Test L2 Error, 0.01589184671640396
# Epoch: 85, Epoch Time: 12.374876760000006, Train MSE_Error: 2.8339463942756992e-05, Train_L2_Error :0.010047591663897038 Test L2 Error, 0.007080281674861908
# Epoch: 86, Epoch Time: 12.569920658999763, Train MSE_Error: 1.3634506190101093e-05, Train_L2_Error :0.00650534238666296 Test L2 Error, 0.005756980255246163
# Epoch: 87, Epoch Time: 12.440899602000172, Train MSE_Error: 2.202664494689088e-05, Train_L2_Error :0.008373964920639992 Test L2 Error, 0.006883900761604309
# Epoch: 88, Epoch Time: 12.3539127009999, Train MSE_Error: 1.2953652230862645e-05, Train_L2_Error :0.006650993257761002 Test L2 Error, 0.012521698921918869
# Epoch: 89, Epoch Time: 12.51388291800049, Train MSE_Error: 3.153416501390893e-05, Train_L2_Error :0.010669084906578063 Test L2 Error, 0.009379426538944245
# Epoch: 90, Epoch Time: 12.58447163999972, Train MSE_Error: 1.7784128767743824e-05, Train_L2_Error :0.00775444608181715 Test L2 Error, 0.005122903436422348
# Epoch: 91, Epoch Time: 12.614459035000436, Train MSE_Error: 1.6895235721676726e-05, Train_L2_Error :0.0075094298049807546 Test L2 Error, 0.009982753694057465
# Epoch: 92, Epoch Time: 12.466384884000036, Train MSE_Error: 2.9053695861875894e-05, Train_L2_Error :0.010333485394716263 Test L2 Error, 0.00902951806783676
# Epoch: 93, Epoch Time: 12.490305627999987, Train MSE_Error: 2.536436049922486e-05, Train_L2_Error :0.00947511913627386 Test L2 Error, 0.010333496779203415
# Epoch: 94, Epoch Time: 12.264453867999691, Train MSE_Error: 2.9286153603607092e-05, Train_L2_Error :0.010095646090805531 Test L2 Error, 0.009940551221370697
# Epoch: 95, Epoch Time: 12.952556057999573, Train MSE_Error: 2.9650849719473626e-05, Train_L2_Error :0.01018189711123705 Test L2 Error, 0.00860847920179367
# Epoch: 96, Epoch Time: 13.405375729000298, Train MSE_Error: 1.671499348958605e-05, Train_L2_Error :0.007361287333071232 Test L2 Error, 0.007374807447195053
# Epoch: 97, Epoch Time: 12.482624742000553, Train MSE_Error: 1.5821257275092648e-05, Train_L2_Error :0.007176687277853489 Test L2 Error, 0.007556488364934921
# Epoch: 98, Epoch Time: 12.795234545000312, Train MSE_Error: 1.852731023063825e-05, Train_L2_Error :0.007963198997080326 Test L2 Error, 0.011806863695383071
# Epoch: 99, Epoch Time: 12.846191863999593, Train MSE_Error: 2.7177716183359736e-05, Train_L2_Error :0.010199665501713752 Test L2 Error, 0.010744513422250747
# Epoch: 100, Epoch Time: 12.833607968999786, Train MSE_Error: 9.008412662296906e-06, Train_L2_Error :0.005161862839013338 Test L2 Error, 0.0059173375368118284
# Epoch: 101, Epoch Time: 12.943421775000388, Train MSE_Error: 7.5975465460942356e-06, Train_L2_Error :0.005065665476024151 Test L2 Error, 0.005514698848128319
# Epoch: 102, Epoch Time: 13.015077791000294, Train MSE_Error: 5.558093660056329e-06, Train_L2_Error :0.0038988095819950104 Test L2 Error, 0.003294268622994423
# Epoch: 103, Epoch Time: 12.931130831999326, Train MSE_Error: 7.180498525940493e-06, Train_L2_Error :0.004564685586839914 Test L2 Error, 0.002672460824251175
# Epoch: 104, Epoch Time: 13.021852378999938, Train MSE_Error: 6.2024454655329465e-06, Train_L2_Error :0.004017657000571489 Test L2 Error, 0.004374458119273185
# Epoch: 105, Epoch Time: 13.121278996000001, Train MSE_Error: 4.059511903733437e-06, Train_L2_Error :0.003092663746327162 Test L2 Error, 0.007562554776668549

# %%
scipy.io.savemat('burger_test.mat', mdict={'pred': pred.cpu().numpy()})

# %%
import matplotlib.gridspec as gridspec
ep,t, e_mse, trn_l2, tst_l2 = np.loadtxt("loss_err_fno.txt", delimiter=' ', usecols=(0, 1,2,3,4), unpack=True)
gs0 = gridspec.GridSpec(1,1)
ax = plt.subplot(gs0[:, :])
ax.semilogy(ep, e_mse, '-k', lw=2.0, label="MSE Train Error")
ax.set_xlabel('$Epoch$')
ax.set_ylabel('$Loss$')
ax.legend(frameon=False, loc = 'best')
ax.set_title('Train Loss', fontsize = 10)
plt.savefig("Train_Loss.png", dpi=300)

plt.show()
gs1 = gridspec.GridSpec(1,1)
ax1 = plt.subplot(gs1[:, :])
ax1.semilogy(ep, trn_l2, '-k', lw=2.0, label="Train L2 Error")
ax1.semilogy(ep, tst_l2, '-r', lw=2.0, label="Test L2 Error")

ax1.set_xlabel('$Epoch$')
ax1.set_ylabel('$Loss$')
ax1.legend(frameon=False, loc = 'best')
ax1.set_title('Train and Test Errors', fontsize = 10)
plt.savefig("Train_Test.png", dpi=300)

plt.show()

ba,e = np.loadtxt("eval_err.txt", delimiter=' ', usecols=(0, 1), unpack=True)
gs2 = gridspec.GridSpec(1,1)
ax2 = plt.subplot(gs1[:, :])
ax2.plot(ba, e, '-k', lw=2.0, label="Train L2 Error")

ax2.set_xlabel('Test Samples')
ax2.set_ylabel("L2 Error")
ax2.legend(frameon=False, loc = 'best')
ax2.set_title('Train and Test Errors', fontsize = 10)
plt.savefig("Error.png", dpi=300)

plt.show()

# %%
pred_u_plot = pred[0,:]
u_test_plot = y_test[0,:]
x_test_plot = x_test[0,:]
x_plot = np.linspace(0, 1, 1024)
err1 = np.linalg.norm(u_test_plot - pred_u_plot)
err2 = np.linalg.norm(u_test_plot)
err = err1/err2
print(f"L2 Error is: {err}")
gs = gridspec.GridSpec(1,1)
ax = plt.subplot(gs[:, :])
ax.plot(x_plot, pred_u_plot, '-k', lw=2.0, label="FNO Predicted")
ax.plot(x_plot, u_test_plot, '--b', lw=2.0, label="Actual Solution")
ax.set_xlabel('$x$')
ax.set_ylabel("u")
ax.legend(frameon=False, loc = 'best')
ax.set_title("Actual vs Predicetd $u$, T=1 with L2 Error = 0.0002", fontsize = 10)
plt.savefig("Solution", dpi=300)


gs = gridspec.GridSpec(1,1)
ax1 = plt.subplot(gs[:, :])
ax1.plot(x_plot, x_test_plot, '-k', lw=2.0, label="Initial Condition")
ax1.set_xlabel('x')
ax1.set_ylabel("u0")
ax1.legend(frameon=False, loc = 'best')
ax1.set_title("Initial Conditions", fontsize = 10)
plt.savefig("Ic_test", dpi=300)
plt.show()
# Out:
# L2 Error is: 0.00020575149392243475

# %%
plt.plot(s1, "-")
plt.plot(s2,"--")
# Out:
# tensor([0.1210, 0.1235, 0.1259,  ..., 0.1138, 0.1163, 0.1188])
